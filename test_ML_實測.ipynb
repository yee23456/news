# %%
import joblib
import pandas as pd
import jieba
df = open('C:/Users/沈睿朋/Documents/github/news/ewr.txt',encoding=('utf-8'))
word = []
word_text = ''
for i in df:
    line = i.splitlines()
    if line == ['']:
        word.append(word_text)
        word_text = ''
    elif line == ['[廣告]請繼續往下閱讀...']:
        continue
    elif line[0][0] == 'h' or line[0][0] == '▲' or line[0][0:2] == '記者' or line[0][0] == '▼':
        continue
    word_text+=i.rstrip()
word.append(word_text)

# %%
clf2 = joblib.load('C:/Users/沈睿朋/Documents/github/news/clf.pkl')
ctv2 = joblib.load('C:/Users/沈睿朋/Documents/github/news/ctv.pkl')
df = pd.DataFrame(word,columns = ['file'])
df['file_Participle'] = df['file'].apply(lambda i:jieba.cut(i) )
df['file_Participle'] =[' '.join(i) for i in df['file_Participle']]
df['test_dis'] = df['file_Participle'] .apply(lambda x : clf2.predict(ctv2.transform([x])))
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['fed', 'jp', 'max', 'qe', 'vtfet'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
#                                                  file  \
# 0   美股連2天走跌，拖累台股今 (7) 日開低走低，台積電領跌，金融股撐盤，不過盤中衛福部長陳時...
# 1   28檔上市櫃「金融股」公布配息，現金殖利率高於5%的共10檔，排名第一的康和證（6016），...
# 2   威力彩頭獎連槓14期，今（7）日頭獎上看6.1億，士林夜市、飛來發彩券行業者黃偉祺接受《ET...
# 3   美聯準會（Fed）發布3月會議紀錄，為因應美國40年來最嚴重的通膨，每年將縮減資產負債表超過...
# 4   晟德（4123）於今（7）日召開記者會宣布，董事會已通過合併子公司「玉晟生技投資股份有限公司...
# 5   據業界消息透露，英特爾執行長基辛格（Pat Gelsinger）將於今日下午五點多，搭乘私人...
# 6   中央銀行上月宣布升息1碼（0.25個百分點），各家公股銀行也跟進宣布調高存款及房貸利率，合庫...
# 7   南韓三星電子今（7）日公布初步Q1業績報告，受惠於新款智慧型手機及伺服器所需記憶體晶片需求攀...
# 8   三星電子Q1營收為77兆韓元，優於分析師預期的74.9兆韓元（約新台幣1.77兆元），這已經...
# 9   美股4大指數下挫，台股一度大跌超過200點，回測月線、力守年線，不過盤中金融撐盤，電子跌幅收...
# 10  本土疫情升溫，科技業、金融業紛紛出現有同仁確診，目前相關員工都已進行PCR檢測，公司也大規模...
# 11  江蘇疫情嚴峻，蘇州昆山昨才宣布4月2~6日停工，但疫情未見好轉，昆山政府表示，封控措施將續延...
# 12  房產中心／桃園報導據統計，近4年桃園中壢火車站周邊的新、舊大樓漲幅皆超過2成，公寓產品也有1...
# 13  日本拉麵深受國人喜愛，近來多家拉麵名店一家一家地開，吸引不少饕客連夜排隊。對此，就有網友在多...
# 14  網搜小組／董美琪報導一名女網友在「爆怨公社」發文表示，住了30幾年的房子這期電費竟然暴漲到4...
# 15  文／傅恪恩／今周刊「下星期六，大家一起來我新家玩吧！」樂威最近新宅入手，呼朋招友來家中一起踩...
# 16  現在要在高雄買到新成屋，難度似乎愈來愈高，根據統計高雄各行政區內70坪以下的成屋庫存水位皆低...
# 17  啟用才剛滿1年的明倫社會住宅，4日早上發生「連續火警警報」觸發狀況，社區保全確認無火災情形後...
# 18  行政院會今（7）日通過內政部所擬具《平均地權條例》修正草案，內容包括重罰炒房行為、管制私法人...
# 19  上月傳出，央行不排除祭出「第二戶限貸令」，造成市場恐慌、民怨四起。新北市不動產開發商業同業公...
# 20  台灣缺工問題存在已久，產業界早在10多年前，就呼籲政府擴大引進外籍移工，但遲遲沒有下文，如今...
# 21  行政院今（7）日拍板《平均地權條例》修正草案，其中消費者最關心的便是預售屋禁換約的限制。專家...
# 22  美國近期發布一項新政策，今年夏天將額外發放3.5萬張H-2B打工簽證，以便為漁業、造景等夏季...
# 23  圖、文／新聯陽機構原屬於國產署公有資產的「板橋區大觀段984地號、新興段1164-10地號」...
# 24  政治中心／台北報導行政院7日拍板內政部擬具的《平均地權條例》修正草案，明文限制換約轉售、重罰...
# 25  行政院會今（7日）通過內政部擬具《平均地權條例》修正草案，修法內容包括：限制預售屋及新建成屋...
# 26  網搜小組／劉維榛報導外送員各個都有一雙飛毛神腿。一名外送哥表示，最近把餐點送到某公寓，爬樓梯...
# 27  網紅「那對夫妻」Kim（京燁）和Nico（品筠）育有一對兒女，包括7歲女兒「妮妮」以及去年底...
# 28  網搜小組／鄺郁庭報導很多人存到一筆錢會用來投資，畢竟不管多麼費勁地存，還是有可能付之東流，但...
# 29  最新實價揭露，悟覺妙天以法人名義，砸2.38億元無貸款買下北市商辦「醒吾大樓」。但師傅的房地...
# 30  行政院會今（7日）通過內政部擬具《平均地權條例》修正草案，修法內容包括：限制預售屋及新建成屋...
# 31  南韓三星電子今（7）日公布初步Q1業績報告，受惠於新款智慧型手機及伺服器所需記憶體晶片需求攀...
# 32  三星電子Q1營收為77兆韓元，優於分析師預期的74.9兆韓元（約新台幣1.77兆元），這已經...
# 33  美國聯邦準備理事會（Fed）可能以激烈升息遏止通膨，美股連跌2個交易日，台股難逃波及，指數今...
# 34  美聯準會（Fed）發布3月會議紀錄，為因應美國40年來最嚴重的通膨，每年將縮減資產負債表超過...
# 35  台股指數今（7）日持續高檔震盪，法人分析指出，近期選股策略首重顯學產業與低位階個股，資金仍會...
# 36  受到聯準會恐鷹派升息並迅速縮表的利空消息衝擊，台北股匯昨（6）日雙雙下挫，貶6.5分，收在2...
# 37  美聯準會（Fed）公布3月會議紀錄，顯示聯準會可能採取強烈貨幣緊縮政策，美股3大指數收低。台...
# 38  宏達電（2498）公布3月營收為4.25億元，月增32%、年減6.45%，Q1合併營收為11...
# 39  美股4大指數下挫，台股一度大跌超過200點，回測月線、力守年線，不過盤中金融撐盤，電子跌幅收...
# 40  為提醒投資人交易風險，證交所祭出當沖占比過高有價證券警示機制，今日共有3檔股票因前一個交易日...
#
#                                       file_Participle test_dis
# 0   美股連 2 天 走跌 ， 拖累 台股 今   ( 7 )   日開 低 走低 ， 台積 電領...      [1]
# 1   28 檔 上市 櫃 「 金融股 」 公布 配息 ， 現金殖 利率 高 於 5% 的 共 10...      [0]
# 2   威力 彩頭 獎連槓 14 期 ， 今 （ 7 ） 日頭 獎上 看 6.1 億 ， 士林 夜市...      [0]
# 3   美聯 準會 （ Fed ） 發布 3 月會議 紀錄 ， 為 因應 美國 40 年 來 最 嚴...      [0]
# 4   晟 德 （ 4123 ） 於 今 （ 7 ） 日召開 記者 會 宣布 ， 董事 會 已通 過...      [1]
# 5   據業界 消息 透露 ， 英特 爾 執行長 基辛格 （ Pat   Gelsinger ） 將...      [1]
# 6   中央 銀行 上 月 宣布 升息 1 碼 （ 0.25 個 百分 點 ） ， 各家 公股 銀行...      [1]
# 7   南韓 三星 電子 今 （ 7 ） 日 公布 初步 Q1 業績 報告 ， 受惠 於 新款 智慧...      [1]
# 8   三星 電子 Q1 營收 為 77 兆 韓元 ， 優 於 分析 師預期 的 74.9 兆 韓元...      [1]
# 9   美股 4 大指數 下挫 ， 台股 一度 大跌 超過 200 點 ， 回測 月 線 、 力守 ...      [1]
# 10  本土 疫情 升溫 ， 科技 業 、 金融 業紛 紛出 現有 同仁 確診 ， 目前 相關員工 ...      [1]
# 11  江蘇 疫情 嚴峻 ， 蘇州 昆山 昨才 宣布 4 月 2 ~ 6 日 停工 ， 但 疫情 未...      [1]
# 12  房產 中心 ／ 桃園 報導據 統計 ， 近 4 年桃園 中壢 火車 站 周邊 的 新 、 舊...      [1]
# 13  日本 拉 麵 深受 國人 喜愛 ， 近來 多家 拉 麵 名店 一家 一家 地開 ， 吸引 不...      [1]
# 14  網搜小組 ／ 董美琪 報導 一名 女 網友 在 「 爆怨 公社 」 發文 表示 ， 住 了 ...      [1]
# 15  文 ／ 傅恪 恩 ／ 今 周刊 「 下 星期六 ， 大家 一起 來 我 新家 玩吧 ！ 」 ...      [1]
# 16  現在 要 在 高雄 買 到 新 成屋 ， 難度 似乎 愈來 愈 高 ， 根據 統計 高雄 各...      [1]
# 17  啟用 才 剛滿 1 年 的 明倫 社會 住宅 ， 4 日 早上 發生 「 連續 火警 警報 ...      [1]
# 18  行政院 會今 （ 7 ） 日通過 內政部 所擬 具 《 平均 地權 條例 》 修正 草案 ，...      [1]
# 19  上 月 傳出 ， 央行 不 排除 祭 出 「 第二 戶限 貸令 」 ， 造成 市場 恐慌 、...      [1]
# 20  台灣 缺工 問題 存在 已 久 ， 產業界 早 在 10 多年 前 ， 就 呼籲 政府 擴大...      [1]
# 21  行政院 今 （ 7 ） 日 拍板 《 平均 地權 條例 》 修正 草案 ， 其中 消費者 最...      [1]
# 22  美國 近期 發布 一項 新 政策 ， 今年夏天 將額外 發放 3.5 萬張 H - 2B 打...      [1]
# 23  圖 、 文 ／ 新聯陽 機構 原屬 於 國產署 公有 資產 的 「 板橋區 大觀 段 984...      [1]
# 24  政治 中心 ／ 台北 報導 行政院 7 日 拍板 內政部 擬具 的 《 平均 地權 條例 》...      [1]
# 25  行政院 會今 （ 7 日 ） 通過 內政部 擬具 《 平均 地權 條例 》 修正 草案 ， ...      [1]
# 26  網搜小組 ／ 劉維 榛 報導外 送員 各個 都 有 一雙飛 毛神 腿 。 一名 外送哥 表示...      [1]
# 27  網紅 「 那 對 夫妻 」 Kim （ 京燁 ） 和 Nico （ 品筠 ） 育有 一對兒 ...      [1]
# 28  網搜小組 ／ 鄺郁庭 報導 很多 人存 到 一筆 錢會用 來 投資 ， 畢竟 不管 多麼 費...      [1]
# 29  最新 實價 揭露 ， 悟 覺妙 天以 法人 名義 ， 砸 2.38 億元 無 貸款 買 下 ...      [1]
# 30  行政院 會今 （ 7 日 ） 通過 內政部 擬具 《 平均 地權 條例 》 修正 草案 ， ...      [1]
# 31  南韓 三星 電子 今 （ 7 ） 日 公布 初步 Q1 業績 報告 ， 受惠 於 新款 智慧...      [1]
# 32  三星 電子 Q1 營收 為 77 兆 韓元 ， 優 於 分析 師預期 的 74.9 兆 韓元...      [1]
# 33  美國 聯邦 準備 理事 會 （ Fed ） 可能 以 激烈 升息 遏止 通 膨 ， 美股 連...      [1]
# 34  美聯 準會 （ Fed ） 發布 3 月會議 紀錄 ， 為 因應 美國 40 年 來 最 嚴...      [0]
# 35  台 股指 數今 （ 7 ） 日持續 高檔 震盪 ， 法人 分析 指出 ， 近期 選股 策略 ...      [1]
# 36  受到 聯準 會 恐鷹 派 升息 並 迅速 縮表 的 利空消息 衝擊 ， 台北 股匯 昨 （ ...      [0]
# 37  美聯 準會 （ Fed ） 公布 3 月會議 紀錄 ， 顯示 聯準 會 可能 採取 強烈 貨...      [1]
# 38  宏達電 （ 2498 ） 公布 3 月 營收 為 4.25 億元 ， 月 增 32% 、 年...      [1]
# 39  美股 4 大指數 下挫 ， 台股 一度 大跌 超過 200 點 ， 回測 月 線 、 力守 ...      [1]
# 40  為 提醒 投資人 交易 風險 ， 證交所 祭 出當 沖 占 比過 高有 價證券 警示 機制 ...      [1]
